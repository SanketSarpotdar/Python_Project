# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb
import sqlalchemy as sq

# %%
en=sq.create_engine("mysql+pymysql://root:sarpotdar%401@localhost/customers")

# %%
df=pd.read_sql("select * from customer_data",en)
print(df)
# Out:
#      customer_id     customer_name  age  gender  income        location  \
# 0           1011  Michelle Russell   38    Male   59.81    East Garrett
# 1           1032     Daniel Harris   33  Female  137.66      Lake Maria
# 2           1043    William Wilson   45  Female  100.86     Wintersland
# 3           1045    Ronald Woodard   37    Male   39.78   Port Jennifer
# 4           1054    Walter Morales   31  Female   51.39    Terrencefort
# ..           ...               ...  ...     ...     ...             ...
# 940         9961    David Garrison   62    Male  123.86     Matthewport
# 941         9965    Shannon Dennis   35   Other  129.13  Kathrynchester
# 942         9969   Samantha Rogers   21   Other  118.25       North Bob
# 943         9973       David Jones   36    Male  142.04      East Kevin
# 944         9978    Theresa Burton   52    Male  112.23    Goodmanhaven
#
#     signup_date
# 0    07-07-2020
# 1    07-12-2023
# 2    07-03-2024
# 3    03-03-2024
# ...

# %%
df.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# age              0
# gender           0
# income           0
# location         0
# signup_date      0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      customer_id     customer_name  age  gender  income        location  \
# 0           1011  Michelle Russell   38    Male   59.81    East Garrett
# 1           1032     Daniel Harris   33  Female  137.66      Lake Maria
# 2           1043    William Wilson   45  Female  100.86     Wintersland
# 3           1045    Ronald Woodard   37    Male   39.78   Port Jennifer
# 4           1054    Walter Morales   31  Female   51.39    Terrencefort
# ..           ...               ...  ...     ...     ...             ...
# 940         9961    David Garrison   62    Male  123.86     Matthewport
# 941         9965    Shannon Dennis   35   Other  129.13  Kathrynchester
# 942         9969   Samantha Rogers   21   Other  118.25       North Bob
# 943         9973       David Jones   36    Male  142.04      East Kevin
# 944         9978    Theresa Burton   52    Male  112.23    Goodmanhaven
#
#     signup_date
# 0    07-07-2020
# 1    07-12-2023
# 2    07-03-2024
# 3    03-03-2024
# ...

# %%
duplicates = df.columns[df.columns.duplicated()]
duplicates
# Out:
# Index([], dtype='object')

# %%
cd=pd.read_csv("customer_data.csv")
cs=pd.read_csv("customer_segments.csv")
prd=pd.read_csv("product_data.csv")
prd1=pd.read_csv("purchase_data.csv")
pfd=pd.read_csv("purchase_frequency_data.csv")

# %%
cd.isnull().sum()
cs.isnull().sum()
prd.isnull().sum()
prd1.isnull().sum()
pfd.isnull().sum()
# Out:
# customer_id           0
# total_purchases       0
# total_spent           0
# avg_purchase_value    0
# purchase_frequency    0
# dtype: int64

# %%
cd
# Out:
#      customer_id        customer_name  age  gender  income        location  \
# 0           8650         Bryan Barker   34  Female  145.93      Smithmouth
# 1           4073    Melanie Brown DDS   69   Other   48.03     Flemingstad
# 2           9340          John Morris   23  Female   44.61    Port Heather
# 3           6230     Victoria Simmons   30    Male   68.76        Riceside
# 4           6473       Jonathan Smith   62   Other   55.24    Robertsmouth
# ..           ...                  ...  ...     ...     ...             ...
# 995         7712         Connor Hodge   61    Male  125.45        Cruzberg
# 996         1203        Stephen Davis   31   Other  141.76  New Andreaport
# 997         4670        Melissa Scott   64    Male  119.49     Pattonville
# 998         2761          Julie Kline   68   Other  104.25      Andreafurt
# 999         4119  Christopher Sweeney   61    Male  121.62       Port Lisa
#
#     signup_date
# 0    2021-12-10
# 1    2023-09-05
# ...

# %%
cs
# Out:
#    segment_id       segment_name                                 criteria
# 0           1      High Spenders        income > 100K, total_spent > 5000
# 1           2  Occasional Buyers            frequency < 2 purchases/month
# 2           3    Loyal Customers                     total_purchases > 50
# 3           4   Discount Seekers    income < 50K, avg_purchase_value < 20
# 4           5    Luxury Shoppers  income > 150K, avg_purchase_value > 500

# %%
prd
# Out:
#      product_id      product_name     category                       brand  \
# 0          2671        Fall Table  Electronics               Boyle-Wilkins
# 1          6445  Discussion Phone  Electronics                Taylor-Smith
# 2          9883        Walk Phone   Home Goods      Boyd, Harvey and Baker
# 3          3893     Couple Laptop  Electronics               Wilkins-Singh
# 4          2804        Dark Phone  Electronics                   Perez PLC
# ..          ...               ...          ...                         ...
# 495        5227        Sell Table       Beauty  Santiago, Price and Powell
# 496        6877        Fine Table        Books              Fuentes-Barber
# 497        5187        Rise Shirt        Books                 Brown Group
# 498        9882  Experience Shirt     Clothing               Perez-Pearson
# 499        5409     Already Phone       Beauty                  Hudson Ltd
#
#       price
# 0    567.24
# 1    995.85
# 2    408.55
# 3    316.97
# ...

# %%
prd1
# Out:
#       purchase_id  customer_id purchase_date  product_id     category  \
# 0          976090         6780    2024-05-14        3017  Electronics
# 1          725237         9831    2024-05-18        1676     Clothing
# 2          200821         5302    2024-01-27        2987  Electronics
# 3          170634         3507    2023-06-14        3533   Home Goods
# 4          603902         1092    2024-01-30        3774       Beauty
# ...           ...          ...           ...         ...          ...
# 9995       555648         3652    2023-03-22        2341       Beauty
# 9996       999897         8486    2022-12-15        6527  Electronics
# 9997       641126         4396    2023-10-14        5036   Home Goods
# 9998       814825         6398    2023-01-29        3986        Books
# 9999       133521         8742    2024-06-28        7441       Beauty
#
#       quantity  price_per_unit  total_amount
# 0            2          230.72        461.44
# ...

# %%
pfd
# Out:
#      customer_id  total_purchases  total_spent  avg_purchase_value  \
# 0           8650                9     24081.22             2675.69
# 1           4073               11     32223.37             2929.40
# 2           9340               21     54087.32             2575.59
# 3           6230               20     72474.99             3623.75
# 4           6473                5     16955.95             3391.19
# ..           ...              ...          ...                 ...
# 995         7712                8     27105.17             3388.15
# 996         1203               15     30873.42             2058.23
# 997         4670               11     28663.12             2605.74
# 998         2761               12     44722.83             3726.90
# 999         4119               24     80468.39             3352.85
#
#      purchase_frequency
# 0                  0.38
# 1                  0.46
# 2                  0.88
# 3                  0.83
# 4                  0.21
# ...

# %%
data=pd.merge(cd,pfd,on="customer_id",how="inner")
data.groupby(by="customer_id").agg({"avg_purchase_value":["count"]})
# Out:
#             avg_purchase_value
#                          count
# customer_id
# 1011                         1
# 1032                         1
# 1043                         1
# 1045                         1
# 1054                         1
# ...                        ...
# 9961                         1
# 9965                         1
# 9969                         1
# 9973                         1
# 9978                         1
#
# [945 rows x 1 columns]

# %%
data1=pd.merge(prd1,pfd,on="customer_id",how="inner")
data1.groupby(by="customer_id").agg({"total_spent":["sum"]})
# Out:
#             total_spent
#                     sum
# customer_id
# 1011          183470.94
# 1032           98711.90
# 1043          131717.16
# 1045          422494.32
# 1054           64217.65
# ...                 ...
# 9961          603629.13
# 9965          715571.40
# 9969          274742.90
# 9973          396129.24
# 9978          196396.48
#
# [945 rows x 1 columns]

# %%
data
# Out:
#       customer_id        customer_name  age  gender  income        location  \
# 0            8650         Bryan Barker   34  Female  145.93      Smithmouth
# 1            4073    Melanie Brown DDS   69   Other   48.03     Flemingstad
# 2            9340          John Morris   23  Female   44.61    Port Heather
# 3            9340          John Morris   23  Female   44.61    Port Heather
# 4            6230     Victoria Simmons   30    Male   68.76        Riceside
# ...           ...                  ...  ...     ...     ...             ...
# 1109         1203        Stephen Davis   31   Other  141.76  New Andreaport
# 1110         4670        Melissa Scott   64    Male  119.49     Pattonville
# 1111         2761          Julie Kline   68   Other  104.25      Andreafurt
# 1112         4119  Christopher Sweeney   61    Male  121.62       Port Lisa
# 1113         4119  Christopher Sweeney   61    Male  121.62       Port Lisa
#
# ...

# %%
# 1] What is the distribution of customers by age group?
plt.figure(figsize=(10, 5))
sb.histplot(df['age'], bins=20, kde=True, color='blue')
plt.title("Distribution of Customer Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 5))
sb.boxplot(x=df['age'], color='blue')
plt.title("Box Plot of Customer Age Distribution")
plt.xlabel("Age")
plt.show()

# %%
# 2] What is the average income of customers by gender?
avg_income_gender = df.groupby('gender')['income'].mean()
plt.figure(figsize=(8, 4))
sb.barplot(x=avg_income_gender.index, y=avg_income_gender.values, palette='coolwarm')
plt.title("Average Income by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Income")
plt.show()

plt.figure(figsize=(8, 5))
sb.boxplot(x=df['gender'], y=df['income'], palette='coolwarm')
plt.title("Income Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Income")
plt.show()
# Out:
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\4085218051.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=avg_income_gender.index, y=avg_income_gender.values, palette='coolwarm')
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\4085218051.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df['gender'], y=df['income'], palette='coolwarm')

# %%
# 3] What is the total revenue generated by each product category?
total_revenue_category = prd1.groupby('category')['total_amount'].sum()
plt.figure(figsize=(10, 5))
sb.barplot(x=total_revenue_category.index, y=total_revenue_category.values, palette='plasma')
plt.title("Total Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

average_revenue_category = prd1.groupby('category')['total_amount'].mean()

# Plot the Average Revenue per Order by Category
plt.figure(figsize=(10, 5))
sb.barplot(x=average_revenue_category.index, y=average_revenue_category.values, palette='viridis')
plt.title("Average Revenue per Order by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Revenue per Order")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\3477349975.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=total_revenue_category.index, y=total_revenue_category.values, palette='plasma')
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\3477349975.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=average_revenue_category.index, y=average_revenue_category.values, palette='viridis')

# %%
# 4] What are the top 10 selling products by total revenue?
top_products = prd1.groupby('product_id')['total_amount'].sum().nlargest(10)
plt.figure(figsize=(10, 5))
sb.barplot(x=top_products.index, y=top_products.values, palette='magma')
plt.title("Top 10 Selling Products by Revenue")
plt.xlabel("Product ID")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()


top_products_qty = prd1.groupby('product_id')['quantity'].sum().nlargest(10)
plt.figure(figsize=(10, 5))
sb.barplot(x=top_products_qty.index, y=top_products_qty.values, palette='cividis')
plt.title("Top 10 Selling Products by Quantity Sold")
plt.xlabel("Product ID")
plt.ylabel("Total Quantity Sold")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\2162998132.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=top_products.index, y=top_products.values, palette='magma')
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\2162998132.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=top_products_qty.index, y=top_products_qty.values, palette='cividis')

# %%
# 5] What is the average purchase value for each product category?
# Count the total number of unique product categories
total_categories = prd1['category'].nunique()
print("Total number of unique product categories:", total_categories)

category_avg_purchase = prd1.groupby('category')['total_amount'].mean()
plt.figure(figsize=(10, 5))
sb.barplot(x=category_avg_purchase.index, y=category_avg_purchase.values, palette='Blues')
plt.title("Average Purchase Value by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Purchase Value")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(9, 4))
sb.boxplot(x='category', y='total_amount', data=prd1, palette='coolwarm')
plt.title("Distribution of Purchase Value by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Purchase Value")
plt.xticks(rotation=45)
plt.show()
# Out:
# Total number of unique product categories: 5
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\2455655789.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=category_avg_purchase.index, y=category_avg_purchase.values, palette='Blues')
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\2455655789.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x='category', y='total_amount', data=prd1, palette='coolwarm')

# %%
# 6] What is the distribution of purchase amounts?
plt.figure(figsize=(10, 5))
sb.histplot(prd1['total_amount'], bins=30, kde=True, color='blue')
plt.title("Distribution of Purchase Amounts")
plt.xlabel("Purchase Amount")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 4))
sb.boxplot(x=prd1['total_amount'], color='green')
plt.title("Box Plot of Purchase Amounts")
plt.xlabel("Purchase Amount")
plt.show()

# %%
# 7] What is the correlation between income and total spent?
plt.figure(figsize=(8, 6))
sb.scatterplot(x=cd['income'], y=pfd['total_spent'], alpha=0.6)
plt.title("Correlation between Income and Total Spent")
plt.xlabel("Income")
plt.ylabel("Total Spent")
plt.show()

plt.figure(figsize=(8, 5))
plt.hexbin(cd['income'], pfd['total_spent'], gridsize=30, cmap='Blues', alpha=0.8)
plt.colorbar(label="Number of Customers")
plt.title("Income vs. Total Spent Density Heatmap")
plt.xlabel("Income")
plt.ylabel("Total Spent")
plt.show()

# %%
# 8] What are the top brands by total revenue?
top_brands = prd1.merge(prd, on='product_id').groupby('brand')['total_amount'].sum().nlargest(10)
plt.figure(figsize=(10, 5))
sb.barplot(x=top_brands.index, y=top_brands.values, palette='coolwarm')
plt.title("Top Brands by Total Revenue")
plt.xlabel("Brand")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

top_brands_qty = prd1.merge(prd, on='product_id').groupby('brand')['quantity'].sum().nlargest(10)
plt.figure(figsize=(6, 6))
plt.pie(top_brands_qty.values, labels=top_brands_qty.index, autopct='%1.1f%%', colors=sb.color_palette('pastel'))
plt.title("Top Brands by Quantity Sold")
plt.show()
# Out:
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\3084158190.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=top_brands.index, y=top_brands.values, palette='coolwarm')

# %%
# 9] How does average purchase value vary by customer age group?
age_bins = [18, 25, 35, 45, 55, 65, 100]
cd['age_group'] = pd.cut(cd['age'], bins=age_bins, labels=["18-24", "25-34", "35-44", "45-54", "55-64", "65+"])
merged_data = cd.merge(pfd, on='customer_id')
plt.figure(figsize=(10, 5))
sb.boxplot(x='age_group', y='avg_purchase_value', data=merged_data, palette='coolwarm')
plt.title("Average Purchase Value by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Average Purchase Value")
plt.show()

# plt.figure(figsize=(8, 5))
# sb.violinplot(x='age_group', y='avg_purchase_value', data=merged_data, palette='viridis', inner='quartile')
# plt.title("Distribution of Average Purchase Value by Age Group")
# plt.xlabel("Age Group")
# plt.ylabel("Average Purchase Value")
# plt.show()
# Out:
# C:\Users\SANKET\AppData\Local\Temp\ipykernel_18032\46450805.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x='age_group', y='avg_purchase_value', data=merged_data, palette='coolwarm')
